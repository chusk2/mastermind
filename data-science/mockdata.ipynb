# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('MOCK_DATA.csv', index_col=0)

# %%
df.head()
# Out:
#    first_name    last_name  gender        city                      email  \
# id
# 1     Rudyard          NaN    Male    Montasik         rdelea0@dion.ne.jp
# 2         Kip          NaN  Female    Saltpond        kskitral1@slate.com
# 3      Beckie      Foulkes  Female  Nacimiento          bfoulkes2@wix.com
# 4      Kassia    MacGorley  Female  San Isidro   kmacgorley3@hubpages.com
# 5       Myrta  Van Arsdall  Female       Cazin  mvanarsdall4@marriott.com
#
#                        position                        company
# id
# 1              Product Engineer   McDermott, Rice and Johnston
# 2   Computer Systems Analyst II  Shanahan, Bradtke and Schmidt
# 3                           NaN                   Leuschke LLC
# 4           Clinical Specialist              Hickle-McLaughlin
# 5                     Professor                    Kuhlman-Von

# %%
df_backup = df.copy(deep=True)

# %%
df['position'].isna().sum()
# Out:
# 14

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 1 to 100
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   first_name  100 non-null    object
#  1   last_name   83 non-null     object
#  2   gender      100 non-null    object
#  3   city        94 non-null     object
#  4   email       100 non-null    object
#  5   position    86 non-null     object
#  6   company     100 non-null    object
# dtypes: object(7)
# memory usage: 6.2+ KB

# %%
df.fillna('not provided', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 1 to 100
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   first_name  100 non-null    object
#  1   last_name   100 non-null    object
#  2   gender      100 non-null    object
#  3   city        100 non-null    object
#  4   email       100 non-null    object
#  5   position    100 non-null    object
#  6   company     100 non-null    object
# dtypes: object(7)
# memory usage: 6.2+ KB

# %%
df.columns
# Out:
# Index(['first_name', 'last_name', 'gender', 'city', 'email', 'position',
#        'company'],
#       dtype='object')

# %%
df.sort_values('last_name')
# Out:
#    first_name     last_name      gender            city  \
# id
# 64    Demetri       Aughton        Male  Novosheshminsk
# 34      Genna      Banstead      Female            Oslo
# 43  Clementia       Barthel  Polygender     Karangmelok
# 73      Audre      Beaulieu      Female          Chrysó
# 27      Zenia       Bertram     Agender        Serdobsk
# ..        ...           ...         ...             ...
# 63     Kalvin  not provided        Male         Koynare
# 78     Sonnie  not provided        Male      Shashemenē
# 77       Aili  not provided      Female    Vale de Vila
# 16      Bobby  not provided        Male       Baltimore
# 1     Rudyard  not provided        Male        Montasik
#
#                           email                        position  \
# id
# 64       daughton1r@plala.or.jp              VP Quality Control
# 34   gbansteadx@theguardian.com  Payment Adjustment Coordinator
# 43          cbarthel16@jugem.jp                 Project Manager
# ...

# %%
is_manager = df['position'].apply(lambda x: 'Manager' in x)  # boolean series
manager_positions = df[is_manager].sort_values('last_name')
manager_positions
# Out:
#    first_name     last_name      gender         city  \
# id
# 43  Clementia       Barthel  Polygender  Karangmelok
# 33      Taber          Boag        Male        Baohe
# 68      Micah        Cooney        Male         Tual
# 56     Miguel     Pleasants     Agender     Shuanghe
# 97      Alene     Sedgemore      Female    Sedlarevo
# 72    Damiano      Steenson        Male      Geneina
# 37     Tawnya       Terbeek      Female      Deskáti
# 81   Meridith          Wyer      Female        Matam
# 78     Sonnie  not provided        Male   Shashemenē
#
#                            email                     position  \
# id
# 43           cbarthel16@jugem.jp              Project Manager
# 33             tboagw@utexas.edu           Recruiting Manager
# 68    mcooney1v@domainmarket.com            Marketing Manager
# 56  mpleasants1j@fastcompany.com            Assistant Manager
# 97          asedgemore2o@npr.org  Information Systems Manager
# ...
